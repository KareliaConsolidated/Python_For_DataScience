# %%
import numpy as np
import pandas as pd

data = pd.read_excel('Datasets/anscombes-quartet.xlsx').dropna()

# %%
print(f"Mean: \n{np.mean(data, axis=0)}")
print('-------'*10)
print(f"Standard Deviation: \n{np.std(data, axis=0)}")
# Out:
# Mean:
# X      9.000000
# Y      7.500909
# X.1    9.000000
# Y.1    7.500909
# X.2    9.000000
# Y.2    7.500000
# X.3    9.000000
# Y.3    7.500909
# dtype: float64
# ----------------------------------------------------------------------
# Standard Deviation:
# X      3.162278
# Y      1.937024
# X.1    3.162278
# Y.1    1.937109
# X.2    3.162278
# Y.2    1.935933
# X.3    3.162278
# Y.3    1.936081
# dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

datasaurus = pd.read_csv('Datasets/DatasaurusDozen.tsv', sep='\t')
dino = datasaurus[datasaurus['dataset'] == 'dino']
plt.scatter(dino['x'], dino['y'])
plt.show()

# %%
colnames = datasaurus['dataset'].unique()

# %%
colnames
# Out:
# array(['dino', 'away', 'h_lines', 'v_lines', 'x_shape', 'star',
#        'high_lines', 'dots', 'circle', 'bullseye', 'slant_up',
#        'slant_down', 'wide_lines'], dtype=object)

# %%
for chart in colnames:
    chart = datasaurus[datasaurus['dataset'] == chart]
    plt.scatter(chart['x'], chart['y'])
    plt.show()
