# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
words = []
for line in open('Dataset/words.txt', 'r'):
    words.append(line)

# %%
len(words)
# Out:
# 235886

# %%
words[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
'Aaron\n'.strip()
# Out:
# 'Aaron'

# %%
'Aaron\n'.strip().lower()
# Out:
# 'aaron'

# %%
words = []
for line in open('Dataset/words.txt', 'r'):
    words.append(line.strip().lower())

# %%
words[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
words = set()
for line in open('Dataset/words.txt', 'r'):
    words.add(line.strip().lower())

# %%
words = {line.strip().lower() for line in open('Dataset/words.txt', 'r')}

# %%
words
# Out:
# {'blastosphere',
#  'unpierceable',
#  'bringal',
#  'sporidiolum',
#  'hibiscus',
#  'watercup',
#  'alumnal',
#  'insuppressive',
#  'pilau',
#  'japishly',
#  'pseudoceratitic',
#  'telemeteorographic',
#  'nonballoting',
#  'autophthalmoscope',
#  'rancidify',
#  'snibbler',
#  'clival',
#  'vitreouslike',
#  'jowser',
#  'hexanedione',
#  'anele',
#  'dehair',
#  'burny',
#  'bessera',
#  'pterocaulon',
#  'agraphia',
#  'reinject',
#  'oxychloride',
#  'carcinoid',
#  'apoplexy',
#  'ophthalmotonometry',
#  'overfile',
#  'lipobranchia',
#  'hepialus',
#  'gave',
#  'theriacal',
#  'hypocleidian',
#  'aerocyst',
#  'circularize',
#  'sampsaean',
#  'cardioneural',
#  'bumbershoot',
#  'toxicophagous',
#  'demisemiquaver',
#  'hawthorny',
#  'indefeatable',
#  'unsyndicated',
#  'unredeeming',
#  'argil',
#  'ultraexpeditious',
#  'usefullish',
#  'sniffishness',
#  'nocturne',
#  'seneschalty',
#  'aminic',
#  'unsubjected',
#  'allantoid',
#  'elaterite',
#  'pacemaker',
# ...

# %%
words = sorted({line.strip().lower() for line in open('Dataset/words.txt', 'r')})

# %%
words
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
#  'abashedly',
# ...

# %%
open('Dataset/francais.txt','r',encoding='latin1').readlines()
# Out:
# ['\n',
#  'a\n',
#  'ab\n',
#  'abaissa\n',
#  'abaissai\n',
#  'abaissaient\n',
#  'abaissais\n',
#  'abaissait\n',
#  'abaissant\n',
#  'abaissas\n',
#  'abaissasse\n',
#  'abaissassent\n',
#  'abaissasses\n',
#  'abaissassiez\n',
#  'abaissassions\n',
#  'abaissâmes\n',
#  'abaissât\n',
#  'abaissâtes\n',
#  'abaisse\n',
#  'abaissement\n',
#  'abaissements\n',
#  'abaissent\n',
#  'abaisser\n',
#  'abaissera\n',
#  'abaisserai\n',
#  'abaisseraient\n',
#  'abaisserais\n',
#  'abaisserait\n',
#  'abaisseras\n',
#  'abaisserez\n',
#  'abaisseriez\n',
#  'abaisserions\n',
#  'abaisserons\n',
#  'abaisseront\n',
#  'abaisses\n',
#  'abaisseur\n',
#  'abaisseurs\n',
#  'abaissez\n',
#  'abaissé\n',
#  'abaissée\n',
#  'abaissées\n',
#  'abaissés\n',
#  'abaissèrent\n',
#  'abaissiez\n',
#  'abaissions\n',
#  'abaissons\n',
#  'abandon\n',
#  'abandonna\n',
#  'abandonnai\n',
#  'abandonnaient\n',
#  'abandonnais\n',
#  'abandonnait\n',
#  'abandonnant\n',
#  'abandonnas\n',
# ...
