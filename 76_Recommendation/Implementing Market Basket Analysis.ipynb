# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# Reading Data From Web
retaildata = pd.read_csv('Data/OnlineRetail.csv')
retaildata.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# #### Data Cleaning

# %%
retaildata['Description'] = retaildata['Description'].str.strip()
retaildata.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
retaildata['InvoiceNo'] = retaildata['InvoiceNo'].astype('str')
retaildata = retaildata[~retaildata['InvoiceNo'].str.contains('C')]
retaildata.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
retaildata['Country'].value_counts()
# Out:
# United Kingdom          487622
# Germany                   9042
# France                    8408
# EIRE                      7894
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1967
# Portugal                  1501
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Unspecified                446
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     295
# Hong Kong                  284
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# ...

# %%
retaildata.shape
# Out:
# (532621, 8)

# %%
# Separating Transactions for Germany
mybasket = retaildata[retaildata['Country']=='Germany'].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')

# %%
mybasket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                          0.0                         0.0
# 536840                          0.0                         0.0
# 536861                          0.0                         0.0
# 536967                          0.0                         0.0
# 536983                          0.0                         0.0
# ...                             ...                         ...
# 581266                          0.0                         0.0
# 581494                          0.0                         0.0
# 581570                          0.0                         0.0
# 581574                          0.0                         0.0
# 581578                          0.0                         0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# ...

# %%
# Converting all Pos Values to 1 and everything else to 0
def encode_units(x):
    if x <= 0:
        return 0
    else:
        return 1

basket_sets = mybasket.applymap(encode_units)    
basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %% [markdown]
# #### Training Model

# %%
# Generating Frequent Itemsets
my_frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)

# %%
my_frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.102845                           (6 RIBBONS RUSTIC CHARM)
# 1   0.070022                        (ALARM CLOCK BAKELIKE PINK)
# 2   0.072210                                (GUMBALL COAT RACK)
# 3   0.091904                           (JAM MAKING SET PRINTED)
# 4   0.078775                          (JUMBO BAG RED RETROSPOT)
# 5   0.100656                       (JUMBO BAG WOODLAND ANIMALS)
# 6   0.078775                               (LUNCH BAG WOODLAND)
# 7   0.085339                  (PACK OF 72 RETROSPOT CAKE CASES)
# 8   0.115974                    (PLASTERS IN TIN CIRCUS PARADE)
# 9   0.107221                         (PLASTERS IN TIN SPACEBOY)
# 10  0.070022                        (PLASTERS IN TIN STRONGMAN)
# 11  0.137856                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 12  0.070022                      (RED RETROSPOT CHARLOTTE BAG)
# 13  0.070022                                (RED RETROSPOT CUP)
# ...

# %%
# Generating Rules
my_rules = association_rules(my_frequent_itemsets, metric='lift', min_threshold=1)

# %%
my_rules
# Out:
#                             antecedents                           consequents  \
# 0  (ROUND SNACK BOXES SET OF4 WOODLAND)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 1    (PLASTERS IN TIN WOODLAND ANIMALS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 2   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 4  (ROUND SNACK BOXES SET OF4 WOODLAND)                  (SPACEBOY LUNCH BOX)
# 5                  (SPACEBOY LUNCH BOX)  (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.245077            0.137856  0.074398    0.303571  2.202098
# 1            0.137856            0.245077  0.074398    0.539683  2.202098
# 2            0.157549            0.245077  0.131291    0.833333  3.400298
# 3            0.245077            0.157549  0.131291    0.535714  3.400298
# ...

# %% [markdown]
# #### Making Recommendations

# %%
basket_sets['ROUND SNACK BOXES SET OF4 WOODLAND'].sum()
# Out:
# 112

# %%
basket_sets['SPACEBOY LUNCH BOX'].sum()
# Out:
# 47

# %%
# Filtering rules based on condition
my_rules[(my_rules['lift'] >= 0.3) & (my_rules['confidence'] >= 0.3)]
# Out:
#                             antecedents                           consequents  \
# 0  (ROUND SNACK BOXES SET OF4 WOODLAND)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 1    (PLASTERS IN TIN WOODLAND ANIMALS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 2   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 5                  (SPACEBOY LUNCH BOX)  (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.245077            0.137856  0.074398    0.303571  2.202098
# 1            0.137856            0.245077  0.074398    0.539683  2.202098
# 2            0.157549            0.245077  0.131291    0.833333  3.400298
# 3            0.245077            0.157549  0.131291    0.535714  3.400298
# 5            0.102845            0.245077  0.070022    0.680851  2.778116
#
#    leverage  conviction
# 0  0.040613    1.237951
# ...
