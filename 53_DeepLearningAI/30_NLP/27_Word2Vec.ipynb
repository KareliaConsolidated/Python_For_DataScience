# %%
# Install gensim
# !pip install -U gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.0.1-cp38-cp38-win_amd64.whl (23.9 MB)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in c:\users\anubhav\anaconda3\lib\site-packages (from gensim) (1.20.2)
# Collecting Cython==0.29.21
#   Downloading Cython-0.29.21-cp38-cp38-win_amd64.whl (1.7 MB)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in c:\users\anubhav\appdata\roaming\python\python38\site-packages (from gensim) (4.0.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in c:\users\anubhav\anaconda3\lib\site-packages (from gensim) (1.5.2)
# Installing collected packages: Cython, gensim
#   Attempting uninstall: Cython
#     Found existing installation: Cython 0.29.14
#     Uninstalling Cython-0.29.14:
#       Successfully uninstalled Cython-0.29.14
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.8.3
#     Uninstalling gensim-3.8.3:
#       Successfully uninstalled gensim-3.8.3
# Successfully installed Cython-0.29.21 gensim-4.0.1

# %%
import gensim.downloader as api

wiki_embeddings = api.load('glove-wiki-gigaword-100')
# Out:
# C:\Users\Anubhav\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %%
wiki_embeddings['king']
# Out:
# array([-0.32307 , -0.87616 ,  0.21977 ,  0.25268 ,  0.22976 ,  0.7388  ,
#        -0.37954 , -0.35307 , -0.84369 , -1.1113  , -0.30266 ,  0.33178 ,
#        -0.25113 ,  0.30448 , -0.077491, -0.89815 ,  0.092496, -1.1407  ,
#        -0.58324 ,  0.66869 , -0.23122 , -0.95855 ,  0.28262 , -0.078848,
#         0.75315 ,  0.26584 ,  0.3422  , -0.33949 ,  0.95608 ,  0.065641,
#         0.45747 ,  0.39835 ,  0.57965 ,  0.39267 , -0.21851 ,  0.58795 ,
#        -0.55999 ,  0.63368 , -0.043983, -0.68731 , -0.37841 ,  0.38026 ,
#         0.61641 , -0.88269 , -0.12346 , -0.37928 , -0.38318 ,  0.23868 ,
#         0.6685  , -0.43321 , -0.11065 ,  0.081723,  1.1569  ,  0.78958 ,
#        -0.21223 , -2.3211  , -0.67806 ,  0.44561 ,  0.65707 ,  0.1045  ,
#         0.46217 ,  0.19912 ,  0.25802 ,  0.057194,  0.53443 , -0.43133 ,
#        -0.34311 ,  0.59789 , -0.58417 ,  0.068995,  0.23944 , -0.85181 ,
#         0.30379 , -0.34177 , -0.25746 , -0.031101, -0.16285 ,  0.45169 ,
#        -0.91627 ,  0.64521 ,  0.73281 , -0.22752 ,  0.30226 ,  0.044801,
#        -0.83741 ,  0.55006 , -0.52506 , -1.7357  ,  0.4751  , -0.70487 ,
#         0.056939, -0.7132  ,  0.089623,  0.41394 , -1.3363  , -0.61915 ,
#        -0.33089 , -0.52881 ,  0.16483 , -0.98878 ], dtype=float32)

# %%
wiki_embeddings.most_similar('king')
# Out:
# [('prince', 0.7682328820228577),
#  ('queen', 0.7507690787315369),
#  ('son', 0.7020888328552246),
#  ('brother', 0.6985775232315063),
#  ('monarch', 0.6977890729904175),
#  ('throne', 0.6919989585876465),
#  ('kingdom', 0.6811409592628479),
#  ('father', 0.6802029013633728),
#  ('emperor', 0.6712858080863953),
#  ('ii', 0.6676074266433716)]

# %% [markdown]
# ### Train our own Model

# %%
import gensim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', 100)

messages = pd.read_csv('data/spam.csv', encoding='latin-1')
messages = messages.drop(labels=['Unnamed: 2','Unnamed: 3','Unnamed: 4'], axis=1)
messages.columns = ['label', 'text']
messages.head()
# Out:
#   label                                                                                                 text
# 0   ham  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1   ham                                                                        Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3   ham                                                    U dun say so early hor... U c already then say...
# 4   ham                                        Nah I don't think he goes to usf, he lives around here though

# %%
messages['text_clean'] = messages['text'].apply(lambda x: gensim.utils.simple_preprocess(x))
messages.head()
# Out:
#   label  ...                                                                                           text_clean
# 0   ham  ...  [go, until, jurong, point, crazy, available, only, in, bugis, great, world, la, buffet, cine, th...
# 1   ham  ...                                                                          [ok, lar, joking, wif, oni]
# 2  spam  ...  [free, entry, in, wkly, comp, to, win, fa, cup, final, tkts, st, may, text, fa, to, to, receive,...
# 3   ham  ...                                                       [dun, say, so, early, hor, already, then, say]
# 4   ham  ...                                [nah, don, think, he, goes, to, usf, he, lives, around, here, though]
#
# [5 rows x 3 columns]

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(messages['text_clean'], messages['label'], test_size=0.2)

# %%
# Train the Word2Vec Model
w2v_model = gensim.models.Word2Vec(X_train, vector_size=100, window=5, min_count=2)

# %%
# Explore the word vector for "king" base on our trained model
w2v_model.wv['king']
# Out:
# array([-3.63749675e-02,  7.30707198e-02,  1.05360569e-02,  1.00087905e-02,
#         8.07996432e-04, -1.16727374e-01,  3.63962613e-02,  1.63540572e-01,
#        -6.41819313e-02, -7.17923492e-02, -3.73431928e-02, -9.46589261e-02,
#         1.80880353e-02,  4.28659543e-02,  3.38377245e-02, -4.97752056e-02,
#         4.73563705e-05, -7.24273920e-02,  2.60326220e-03, -1.48279428e-01,
#         4.01377752e-02,  1.09741166e-02,  3.32444943e-02, -4.55698594e-02,
#        -1.66757163e-02, -1.52918659e-02, -5.64211421e-02, -5.39769381e-02,
#        -5.99836558e-02,  1.64108141e-03,  8.41459930e-02,  7.66859623e-03,
#         4.07977775e-02, -7.44729713e-02, -2.27353163e-02,  9.04192179e-02,
#         1.78546109e-03, -5.49667552e-02, -5.40175065e-02, -9.67605039e-02,
#         2.43959781e-02, -6.05602190e-02, -2.89939325e-02,  6.38529018e-04,
#         4.53374758e-02, -1.96593218e-02, -5.94277307e-02, -1.09174447e-02,
#         7.03589842e-02,  3.68493274e-02,  4.55125384e-02, -4.82928455e-02,
#        -1.40669532e-02, -2.06242409e-02, -2.99085770e-02,  3.13008092e-02,
#         2.43656058e-02, -7.22360332e-03, -5.21928407e-02,  4.08853255e-02,
#         1.07738357e-02,  1.53780654e-02, -7.35169696e-03,  2.96261534e-02,
#        -6.77229092e-02,  9.91575345e-02,  3.98490205e-02,  6.76413849e-02,
#        -9.02464017e-02,  1.06391080e-01, -4.57397588e-02,  4.44860496e-02,
#         7.17101246e-02, -3.85068916e-02,  8.79932344e-02,  9.77653824e-03,
#        -1.96298072e-03,  8.91998410e-03, -5.34533896e-02,  1.41525827e-02,
#        -5.01839519e-02, -1.45117696e-02, -8.70777592e-02,  1.04893871e-01,
#        -2.50067841e-02, -8.50134250e-03,  3.89958806e-02,  4.65975292e-02,
#         9.75568071e-02,  9.25573055e-03,  7.76810944e-02,  5.92136532e-02,
#         2.81869266e-02,  2.15542037e-02,  1.25533238e-01,  6.12297468e-02,
#         2.87467036e-02, -7.08789527e-02,  2.06315704e-02, -1.24141062e-02],
#       dtype=float32)

# %%
# Find the most similar words to "king" based on word vectors from our trained model
w2v_model.wv.most_similar('king')
# Out:
# [('tone', 0.9953321814537048),
#  ('week', 0.9952870011329651),
#  ('just', 0.9952313899993896),
#  ('ur', 0.995209276676178),
#  ('start', 0.9952032566070557),
#  ('im', 0.9951218366622925),
#  ('message', 0.995063304901123),
#  ('phone', 0.9950345754623413),
#  ('orange', 0.9950312376022339),
#  ('hello', 0.995023250579834)]

# %% [markdown]
# ### Prep Word Vectors

# %%
# Generate a list of words the word2vec model learned word vectors for
w2v_model.wv.index_to_key
# Out:
# ['to',
#  'you',
#  'the',
#  'and',
#  'is',
#  'in',
#  'me',
#  'it',
#  'my',
#  'for',
#  'your',
#  'call',
#  'of',
#  'that',
#  'have',
#  'on',
#  'now',
#  'can',
#  'are',
#  'so',
#  'but',
#  'not',
#  'or',
#  'do',
#  'we',
#  'get',
#  'at',
#  'with',
#  'ur',
#  'if',
#  'no',
#  'will',
#  'be',
#  'just',
#  'this',
#  'how',
#  'gt',
#  'lt',
#  'go',
#  'up',
#  'when',
#  'ok',
#  'what',
#  'free',
#  'from',
#  'all',
#  'out',
#  'll',
#  'know',
#  'am',
#  'like',
#  'then',
#  'only',
#  'was',
#  'he',
#  'good',
#  'there',
#  'come',
#  'got',
#  'day',
#  'its',
#  'time',
#  'love',
#  'text',
#  'send',
#  'want',
#  'txt',
#  'as',
#  'by',
#  'one',
#  'need',
#  'going',
#  'lor',
#  'home',
#  'today',
#  'about',
#  'still',
#  'don',
#  'stop',
#  'she',
#  'see',
#  'da',
#  'sorry',
#  'mobile',
#  'back',
#  'our',
#  'pls',
#  'take',
#  'any',
#  'new',
#  'did',
#  'dont',
#  'reply',
#  'tell',
#  'ì_',
#  'they',
#  'later',
#  'please',
#  'hi',
#  'much',
#  'some',
#  'claim',
#  'great',
#  'week',
#  'think',
#  'phone',
#  'her',
#  'been',
#  'where',
#  'dear',
#  'here',
#  'has',
#  'too',
#  'msg',
#  're',
#  'night',
#  'oh',
#  'more',
#  'way',
#  'had',
#  'him',
#  'wat',
#  'who',
#  'happy',
#  'hey',
#  'hope',
#  'well',
#  'yes',
#  'won',
#  'give',
#  'make',
#  'an',
#  'number',
#  'prize',
#  'tomorrow',
#  'work',
#  've',
#  'after',
#  'www',
#  'say',
#  'doing',
#  'meet',
#  'ask',
#  'amp',
#  'said',
#  'really',
#  'yeah',
#  'message',
#  'im',
#  'cash',
#  'should',
#  'why',
#  'babe',
#  'anything',
#  'them',
#  'last',
#  'right',
#  'life',
#  'very',
#  'already',
#  'cos',
#  'morning',
#  'would',
#  'win',
#  'nokia',
#  'com',
#  'thanks',
#  'let',
#  'min',
#  'care',
#  'find',
#  'miss',
#  'something',
#  'pick',
#  'lol',
#  'urgent',
#  'also',
#  'cant',
#  'before',
#  'uk',
#  'contact',
#  'sent',
#  'wait',
#  'someone',
#  'many',
#  'us',
#  'were',
#  'over',
#  'keep',
#  'sleep',
#  'every',
#  'buy',
#  'could',
#  'again',
#  'late',
#  'sure',
#  'per',
#  'gonna',
#  'mins',
#  'thing',
#  'help',
#  'went',
#  'next',
#  'customer',
#  'place',
#  'friends',
#  'told',
#  'around',
#  'first',
#  'box',
#  'nice',
#  'sms',
#  'waiting',
#  'chat',
#  'soon',
#  'other',
#  'tonight',
#  'dun',
#  'his',
#  'off',
#  'name',
#  'which',
#  'hello',
#  'even',
#  'haha',
#  'coming',
#  'ìï',
#  'tone',
#  'feel',
#  'getting',
#  'ya',
#  'money',
#  'st',
#  'always',
#  'service',
#  'wish',
#  'wan',
#  'guaranteed',
#  'down',
#  'friend',
#  'leave',
#  'gud',
#  'try',
#  'ppm',
#  'didn',
#  'yet',
#  'heart',
#  'fine',
#  'class',
#  'co',
#  'live',
#  'year',
#  'th',
#  'pm',
#  'may',
#  'thk',
#  'people',
#  'god',
#  'same',
#  'done',
#  'person',
#  'thought',
#  'special',
#  'days',
#  'things',
#  'yup',
#  'finish',
#  'cs',
#  'being',
#  'draw',
#  'line',
#  'best',
#  'lunch',
#  'holiday',
#  'sir',
#  'trying',
#  'man',
#  'meeting',
#  'talk',
#  'stuff',
#  'check',
#  'dat',
#  'use',
#  'lar',
#  'eat',
#  'few',
#  'car',
#  'job',
#  'pobox',
#  'mind',
#  'never',
#  'chance',
#  'smile',
#  'camera',
#  'awarded',
#  'real',
#  'better',
#  'long',
#  'bit',
#  'enjoy',
#  'problem',
#  'house',
#  'half',
#  'account',
#  'hrs',
#  'world',
#  'word',
#  'thats',
#  'ill',
#  'having',
#  'wanna',
#  'liao',
#  'lot',
#  'luv',
#  'because',
#  'cool',
#  'birthday',
#  'shit',
#  'month',
#  'big',
#  'latest',
#  'play',
#  'guess',
#  'end',
#  'pa',
#  'once',
#  'into',
#  'ready',
#  'bed',
#  'room',
#  'face',
#  'shows',
#  'yo',
#  'speak',
#  'than',
#  'reach',
#  'nd',
#  'bt',
#  'girl',
#  'nothing',
#  'early',
#  'offer',
#  'ever',
#  'made',
#  'landline',
#  'start',
#  'forgot',
#  'xxx',
#  'sat',
#  'po',
#  'watching',
#  'quite',
#  'nite',
#  'pay',
#  'orange',
#  'apply',
#  'aight',
#  'receive',
#  'didnt',
#  'cost',
#  'tv',
#  'den',
#  'those',
#  'baby',
#  'rate',
#  'dinner',
#  'wk',
#  'thanx',
#  'ah',
#  'watch',
#  'might',
#  'boy',
#  'leh',
#  'sweet',
#  'wont',
#  'easy',
#  'between',
#  'part',
#  'code',
#  'says',
#  'another',
#  'put',
#  'office',
#  'minutes',
#  'called',
#  'guys',
#  'true',
#  'shopping',
#  'missing',
#  'dunno',
#  'valid',
#  'remember',
#  'plus',
#  'gift',
#  'anyway',
#  'school',
#  'fun',
#  'maybe',
#  'jus',
#  'xmas',
#  'two',
#  'tones',
#  'shall',
#  'sexy',
#  'evening',
#  'working',
#  'without',
#  'looking',
#  'age',
#  'bus',
#  'ringtone',
#  'abt',
#  'details',
#  'video',
#  'while',
#  'years',
#  'hear',
#  'dis',
#  'network',
#  'weekend',
#  'asked',
#  'juz',
#  'collect',
#  'mail',
#  'left',
#  'hour',
#  'wake',
#  'price',
#  'selected',
#  'til',
#  'does',
#  'texts',
#  'important',
#  'probably',
#  'actually',
#  'online',
#  'dad',
#  'optout',
#  'xx',
#  'attempt',
#  'join',
#  'okay',
#  'bad',
#  'wot',
#  'though',
#  'guy',
#  'princess',
#  'plan',
#  'yesterday',
#  'since',
#  'bring',
#  'fuck',
#  'double',
#  'little',
#  'oso',
#  'missed',
#  'wife',
#  'else',
#  'award',
#  'wanted',
#  'havent',
#  'mob',
#  'net',
#  'tmr',
#  'kiss',
#  'lose',
#  'id',
#  'afternoon',
#  'until',
#  'enough',
#  'town',
#  'answer',
#  'alright',
#  'hav',
#  'colour',
#  'food',
#  'collection',
#  'haf',
#  'look',
#  'times',
#  'show',
#  'saw',
#  'thank',
#  'haven',
#  'entry',
#  'came',
#  'bonus',
#  'pain',
#  'weekly',
#  'bored',
#  'makes',
#  'book',
#  'shop',
#  'de',
#  'set',
#  'hair',
#  'poly',
#  'run',
#  'order',
#  'full',
#  'friendship',
#  'sch',
#  'must',
#  'either',
#  'hurt',
#  'family',
#  'believe',
#  'update',
#  'okie',
#  'decimal',
#  'hot',
#  'vouchers',
#  'these',
#  'change',
#  'ard',
#  'means',
#  'able',
#  'mean',
#  'game',
#  'national',
#  'huh',
#  'goin',
#  'worry',
#  'wif',
#  'trip',
#  'wen',
#  'test',
#  'calls',
#  'eve',
#  'simple',
#  'calling',
#  'till',
#  'address',
#  'second',
#  'doesn',
#  'smiling',
#  'hours',
#  'everything',
#  'story',
#  'pics',
#  'gr',
#  'nt',
#  'comes',
#  'most',
#  'dude',
#  'angry',
#  'tomo',
#  'busy',
#  'away',
#  'plz',
#  'driving',
#  'movie',
#  'drive',
#  'brother',
#  'saying',
#  'head',
#  'pic',
#  'sun',
#  'worth',
#  'minute',
#  'tried',
#  'services',
#  'close',
#  'http',
#  'email',
#  'sad',
#  'stay',
#  'suite',
#  'old',
#  'available',
#  'everyone',
#  'noe',
#  'tot',
#  'finished',
#  'charge',
#  'cause',
#  'music',
#  'beautiful',
#  'messages',
#  'coz',
#  'ring',
#  'alone',
#  'sae',
#  'touch',
#  'chikku',
#  'lei',
#  'date',
#  'both',
#  'treat',
#  'hl',
#  'final',
#  'delivery',
#  'leaving',
#  'wants',
#  'goes',
#  'private',
#  'points',
#  'info',
#  'fucking',
#  'took',
#  'together',
#  'walk',
#  'found',
#  'ltd',
#  'mths',
#  'row',
#  'wil',
#  'mum',
#  'club',
#  'carlos',
#  'outside',
#  'pounds',
#  'land',
#  'yr',
#  'light',
#  'voucher',
#  'lucky',
#  'rite',
#  'await',
#  'dreams',
#  'forget',
#  'drink',
#  'mine',
#  'question',
#  'yourself',
#  'wonderful',
#  'card',
#  'fancy',
#  'pub',
#  'sounds',
#  'news',
#  'savamob',
#  'words',
#  'goodmorning',
#  'top',
#  'darlin',
#  'offers',
#  'thinking',
#  'aft',
#  'visit',
#  'auction',
#  'tho',
#  'choose',
#  'winner',
#  'boytoy',
#  'hand',
#  'operator',
#  'mom',
#  'ha',
#  'feeling',
#  'taking',
#  'girls',
#  'company',
#  'making',
#  'todays',
#  'meant',
#  'bank',
#  'loving',
#  'happen',
#  'mrng',
#  'gone',
#  'smoke',
#  'sleeping',
#  'yours',
#  'post',
#  'whatever',
#  'saturday',
#  'mobileupd',
#  'gbp',
#  'expires',
#  'awesome',
#  'each',
#  'cut',
#  'break',
#  'college',
#  'dating',
#  'happened',
#  'identifier',
#  'hmm',
#  'blue',
#  'lesson',
#  'reason',
#  'statement',
#  'used',
#  'eh',
#  'parents',
#  'motorola',
#  'unsubscribe',
#  'camcorder',
#  'wid',
#  'û_',
#  'lets',
#  'their',
#  'type',
#  'whats',
#  'lands',
#  'whole',
#  'park',
#  'party',
#  'enter',
#  'read',
#  'listen',
#  'neva',
#  'hit',
#  'cum',
#  'gd',
#  'chennai',
#  'opt',
#  'frnd',
#  'anyone',
#  'friday',
#  'project',
#  'telling',
#  'congratulations',
#  'jay',
#  'lost',
#  'ass',
#  'txts',
#  'ish',
#  'takes',
#  'india',
#  'finally',
#  'search',
#  'march',
#  'games',
#  'reading',
#  'least',
#  'lovely',
#  'hard',
#  'player',
#  'quiz',
#  'sunday',
#  'log',
#  'caller',
#  'die',
#  'started',
#  'decided',
#  'months',
#  'far',
#  'welcome',
#  'point',
#  'tc',
#  'ans',
#  'secret',
#  'discount',
#  'congrats',
#  'charged',
#  'wasn',
#  'christmas',
#  'pretty',
#  'within',
#  'questions',
#  'difficult',
#  'understand',
#  'wow',
#  'grins',
#  'kind',
#  'supposed',
#  'mobiles',
#  'support',
#  'course',
#  'luck',
#  'oredi',
#  'snow',
#  'bout',
#  'talking',
#  'fri',
#  'case',
#  'open',
#  'nope',
#  'msgs',
#  'heard',
#  'hmv',
#  'swing',
#  'area',
#  'yar',
#  'sis',
#  'prob',
#  'feels',
#  'fast',
#  'knw',
#  'hungry',
#  'crazy',
#  'mu',
#  'mr',
#  'tired',
#  'wrong',
#  'asap',
#  'press',
#  'knew',
#  'hows',
#  'police',
#  'wana',
#  'ago',
#  'met',
#  'anytime',
#  'gets',
#  'drop',
#  'wq',
#  'plans',
#  'ten',
#  'doin',
#  'mah',
#  'study',
#  'yrs',
#  'happiness',
#  'balance',
#  'frnds',
#  'content',
#  'gotta',
#  'exam',
#  'valued',
#  'eg',
#  'earlier',
#  'sub',
#  'father',
#  'ni',
#  'direct',
#  'confirm',
#  'un',
#  'seeing',
#  'phones',
#  'ntt',
#  'hmmm',
#  'store',
#  'poor',
#  'convey',
#  'comin',
#  'muz',
#  'seen',
#  'sea',
#  'somebody',
#  'sister',
#  'thinks',
#  'side',
#  'sound',
#  'kate',
#  'almost',
#  'felt',
#  'song',
#  'wit',
#  'sending',
#  'hee',
#  'stupid',
#  'empty',
#  'red',
#  'wine',
#  'crave',
#  'ts',
#  'couple',
#  'computer',
#  'frm',
#  'usf',
#  'correct',
#  'unlimited',
#  'comp',
#  'reward',
#  'semester',
#  'download',
#  'extra',
#  'dnt',
#  'callertune',
#  'match',
#  'lovable',
#  'surprise',
#  'fr',
#  'etc',
#  'rental',
#  'mayb',
#  'copy',
#  'cheap',
#  'digital',
#  'against',
#  'ex',
#  'comuk',
#  'gn',
#  'weeks',
#  'smth',
#  'laugh',
#  'clean',
#  'isn',
#  'gal',
#  'voice',
#  'redeemed',
#  'numbers',
#  'lect',
#  'checking',
#  'slowly',
#  'hoping',
#  'information',
#  'rd',
#  'remove',
#  'bill',
#  'charity',
#  'lots',
#  'hold',
#  'john',
#  'deep',
#  'na',
#  'sell',
#  'valentines',
#  'ipod',
#  'needs',
#  'move',
#  'invited',
#  'fact',
#  'write',
#  'wondering',
#  'bslvyl',
#  'short',
#  'entered',
#  'myself',
#  'fone',
#  'dogging',
#  'gas',
#  'ûò',
#  'mate',
#  'via',
#  'joy',
#  'sex',
#  'bluetooth',
#  'men',
#  'credit',
#  'paper',
#  'woke',
#  'uncle',
#  'starts',
#  'leaves',
#  'cr',
#  'somewhere',
#  'sk',
#  'through',
#  'complimentary',
#  'studying',
#  'rest',
#  'figure',
#  'sort',
#  'inc',
#  'askd',
#  'txting',
#  'unless',
#  'sony',
#  'train',
#  'street',
#  'asking',
#  'tel',
#  'hg',
#  'tonite',
#  'bold',
#  'booked',
#  'nigeria',
#  'yahoo',
#  'truth',
#  'tickets',
#  'fingers',
#  'cute',
#  'mark',
#  'none',
#  'ive',
#  'funny',
#  'otherwise',
#  'fantastic',
#  'specially',
#  'pizza',
#  'user',
#  'future',
#  'seriously',
#  'slave',
#  'rates',
#  'normal',
#  'pass',
#  'del',
#  'however',
#  'la',
#  'rply',
#  'road',
#  'registered',
#  'wishes',
#  'mrt',
#  'ldn',
#  'representative',
#  'rent',
#  'hw',
#  'bathe',
#  'south',
#  'currently',
#  'save',
#  'gave',
#  'doesnt',
#  'nobody',
#  'nah',
#  'fullonsms',
#  'worries',
#  'sign',
#  'whenever',
#  'ringtones',
#  'kick',
#  'wonder',
#  'ends',
#  'loved',
#  ...]

# %%
# Generate aggregated sentence vectors based on the word vectors for each word in the sentence
w2v_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in w2v_model.wv.index_to_key]) for ls in X_test])
# Out:
# <ipython-input-19-d35c2e4d9bd2>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   w2v_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in w2v_model.wv.index_to_key]) for ls in X_test])

# %%
# Why is the length of the sentences different than the length of the sentence vector ?
for i, v in enumerate(w2v_vect):
    print(len(X_test.iloc[i]), len(v))
# Out:
#
# 16 15
# 5 5
# 6 3
# 13 11
# 19 16
# 28 26
# 16 15
# 7 7
# 38 19
# 8 6
# 20 16
# 30 28
# 7 5
# 16 16
# 28 26
# 21 21
# 7 7
# 25 24
# 14 12
# 5 5
# 13 7
# 22 22
# 6 6
# 10 8
# 41 35
# 8 5
# 17 14
# 2 2
# 17 16
# 13 12
# 23 23
# 5 2
# 6 6
# 27 27
# 19 16
# 6 3
# 15 13
# 11 11
# 18 13
# 18 17
# 23 23
# 12 10
# 13 13
# 58 53
# 15 14
# 12 11
# 22 19
# 16 14
# 4 1
# 7 7
# 5 4
# 1 1
# 21 18
# 22 18
# 16 13
# 8 8
# 7 5
# 28 23
# 5 5
# 19 18
# 29 27
# 5 5
# 6 6
# 7 7
# 26 25
# 11 9
# 12 12
# 27 24
# 4 4
# 10 9
# 16 15
# 20 19
# 46 42
# 2 2
# 16 16
# 7 6
# 12 12
# 21 14
# 11 11
# 8 7
# 4 3
# 13 12
# 8 8
# 12 11
# 5 5
# 24 24
# 9 7
# 14 13
# 21 21
# 11 11
# 25 19
# 24 24
# 16 14
# 4 4
# 19 17
# 4 2
# 4 3
# 2 2
# 36 31
# 16 14
# 15 15
# 9 6
# 13 12
# 21 20
# 10 8
# 9 8

# %%
# Compute sentence vectors by averaging the word vectors for the words contained in the sentence

w2v_vect_avg = []

for vect in w2v_vect:
    if len(vect) != 0:
        w2v_vect_avg.append(vect.mean(axis=0))
    else:
        w2v_vect_avg.append(np.zeros(100))

# %%
for i, v in enumerate(w2v_vect_avg):
    print(len(X_test.iloc[i]), len(v))
# Out:
# 18 100
# 24 100
# 6 100
# 18 100
# 7 100
# 11 100
# 10 100
# 8 100
# 8 100
# 5 100
# 22 100
# 9 100
# 14 100
# 2 100
# 21 100
# 29 100
# 21 100
# 4 100
# 14 100
# 12 100
# 9 100
# 9 100
# 4 100
# 26 100
# 14 100
# 5 100
# 40 100
# 14 100
# 14 100
# 3 100
# 55 100
# 16 100
# 19 100
# 24 100
# 7 100
# 4 100
# 5 100
# 6 100
# 12 100
# 5 100
# 21 100
# 5 100
# 12 100
# 6 100
# 22 100
# 29 100
# 29 100
# 20 100
# 11 100
# 27 100
# 81 100
# 29 100
# 9 100
# 3 100
# 25 100
# 26 100
# 5 100
# 19 100
# 27 100
# 18 100
# 5 100
# 35 100
# 29 100
# 6 100
# 24 100
# 10 100
# 12 100
# 26 100
# 25 100
# 11 100
# 9 100
# 6 100
# 8 100
# 9 100
# 12 100
# 8 100
# 18 100
# 4 100
# 28 100
# 22 100
# 15 100
# 28 100
# 27 100
# 19 100
# 23 100
# 9 100
# 20 100
# 10 100
# 5 100
# 6 100
# 27 100
# 3 100
# 10 100
# 19 100
# 13 100
# 23 100
# 10 100
# 4 100
# 24 100
# 9 100
# 5 100
# 18 100
# 4 100
# 4 100
# 7 100
# 8 100
# 6 100
# 24 100
# 15 100
# 4 100
# 15 100
# 7 100
# 11 100
# 5 100
# 36 100
# 5 100
# 17 100
# 7 100
# 16 100
# 5 100
# 6 100
# 18 100
# 6 100
# 13 100
# 13 100
# 4 100
# 10 100
# 12 100
# 14 100
# 38 100
# 20 100
# 30 100
# 9 100
# 18 100
# 2 100
# 22 100
# 5 100
# 21 100
# 26 100
# 17 100
# 5 100
# 5 100
# 25 100
# 5 100
# 9 100
# 19 100
# 4 100
# 5 100
# 21 100
# 13 100
# 7 100
# 10 100
# 12 100
# 14 100
# 14 100
# 20 100
# 33 100
# 10 100
# 21 100
# 6 100
# 6 100
# 30 100
# 24 100
# 8 100
# 9 100
# 5 100
# 9 100
# 11 100
# 13 100
# 4 100
# 7 100
# 22 100
# 5 100
# 4 100
# 14 100
# 10 100
# 8 100
# 5 100
# 18 100
# 20 100
# 25 100
# 6 100
# 22 100
# 24 100
# 19 100
# 10 100
# 27 100
# 9 100
# 18 100
# 4 100
# 4 100
# 22 100
# 8 100
# 5 100
# 13 100
# 7 100
# 10 100
# 13 100
# 8 100
# 19 100
# 21 100
# 17 100
# 16 100
# 5 100
# 10 100
# 13 100
# 6 100
# 15 100
# 23 100
# 4 100
# 9 100
# 9 100
# 9 100
# 15 100
# 21 100
# 6 100
# 11 100
# 25 100
# 4 100
# 11 100
# 5 100
# 8 100
# 5 100
# 19 100
# 6 100
# 11 100
# 11 100
# 26 100
# 8 100
# 17 100
# 28 100
# 5 100
# 31 100
# 7 100
# 15 100
# 6 100
# 6 100
# 11 100
# 7 100
# 16 100
# 6 100
# 11 100
# 1 100
# 8 100
# 46 100
# 5 100
# 7 100
# 4 100
# 6 100
# 19 100
# 21 100
# 27 100
# 10 100
# 16 100
# 10 100
# 9 100
# 12 100
# 8 100
# 30 100
# 9 100
# 29 100
# 5 100
# 6 100
# 17 100
# 16 100
# 9 100
# 9 100
# 6 100
# 25 100
# 16 100
# 27 100
# 7 100
# 8 100
# 23 100
# 5 100
# 5 100
# 5 100
# 2 100
# 6 100
# 24 100
# 6 100
# 25 100
# 14 100
# 10 100
# 7 100
# 10 100
# 5 100
# 12 100
# 9 100
# 4 100
# 9 100
# 4 100
# 2 100
# 22 100
# 22 100
# 9 100
# 7 100
# 32 100
# 9 100
# 28 100
# 7 100
# 19 100
# 7 100
# 20 100
# 27 100
# 14 100
# 5 100
# 3 100
# 9 100
# 13 100
# 17 100
# 9 100
# 7 100
# 10 100
# 26 100
# 13 100
# 23 100
# 15 100
# 9 100
# 16 100
# 5 100
# 8 100
# 5 100
# 8 100
# 6 100
# 12 100
# 23 100
# 9 100
# 26 100
# 4 100
# 12 100
# 8 100
# 11 100
# 24 100
# 29 100
# 3 100
# 21 100
# 10 100
# 8 100
# 29 100
# 25 100
# 5 100
# 7 100
# 17 100
# 10 100
# 4 100
# 28 100
# 11 100
# 6 100
# 24 100
# 21 100
# 51 100
# 14 100
# 4 100
# 5 100
# 9 100
# 25 100
# 14 100
# 17 100
# 8 100
# 11 100
# 15 100
# 4 100
# 23 100
# 16 100
# 29 100
# 13 100
# 17 100
# 20 100
# 8 100
# 5 100
# 8 100
# 8 100
# 3 100
# 6 100
# 12 100
# 4 100
# 6 100
# 7 100
# 21 100
# 11 100
# 6 100
# 28 100
# 20 100
# 14 100
# 21 100
# 13 100
# 5 100
# 29 100
# 5 100
# 8 100
# 7 100
# 6 100
# 28 100
# 31 100
# 18 100
# 9 100
# 5 100
# 6 100
# 5 100
# 6 100
# 5 100
# 12 100
# 54 100
# 36 100
# 27 100
# 29 100
# 14 100
# 8 100
# 9 100
# 18 100
# 10 100
# 30 100
# 12 100
# 14 100
# 9 100
# 9 100
# 26 100
# 8 100
# 20 100
# 12 100
# 10 100
# 14 100
# 16 100
# 37 100
# 26 100
# 10 100
# 29 100
# 21 100
# 33 100
# 5 100
# 28 100
# 21 100
# 12 100
# 13 100
# 14 100
# 7 100
# 13 100
# 24 100
# 6 100
# 23 100
# 6 100
# 9 100
# 14 100
# 26 100
# 22 100
# 8 100
# 27 100
# 7 100
# 16 100
# 25 100
# 11 100
# 5 100
# 4 100
# 9 100
# 8 100
# 4 100
# 7 100
# 29 100
# 16 100
# 5 100
# 13 100
# 21 100
# 18 100
# 14 100
# 9 100
# 23 100
# 26 100
# 4 100
# 18 100
# 25 100
# 10 100
# 9 100
# 25 100
# 11 100
# 4 100
# 23 100
# 25 100
# 8 100
# 9 100
# 3 100
# 9 100
# 28 100
# 6 100
# 17 100
# 22 100
# 7 100
# 22 100
# 16 100
# 1 100
# 6 100
# 27 100
# 7 100
# 20 100
# 14 100
# 7 100
# 22 100
# 25 100
# 23 100
# 9 100
# 10 100
# 7 100
# 30 100
# 10 100
# 7 100
# 27 100
# 8 100
# 1 100
# 7 100
# 14 100
# 23 100
# 5 100
# 23 100
# 3 100
# 26 100
# 12 100
# 6 100
# 13 100
# 9 100
# 6 100
# 8 100
# 10 100
# 3 100
# 4 100
# 30 100
# 20 100
# 18 100
# 6 100
# 5 100
# 6 100
# 10 100
# 10 100
# 14 100
# 12 100
# 13 100
# 9 100
# 10 100
# 7 100
# 15 100
# 18 100
# 6 100
# 30 100
# 21 100
# 31 100
# 7 100
# 4 100
# 9 100
# 18 100
# 12 100
# 7 100
# 13 100
# 6 100
# 9 100
# 30 100
# 14 100
# 25 100
# 6 100
# 8 100
# 10 100
# 7 100
# 18 100
# 22 100
# 22 100
# 24 100
# 23 100
# 8 100
# 26 100
# 6 100
# 7 100
# 8 100
# 14 100
# 8 100
# 22 100
# 9 100
# 7 100
# 22 100
# 27 100
# 6 100
# 27 100
# 5 100
# 16 100
# 5 100
# 18 100
# 12 100
# 5 100
# 6 100
# 14 100
# 26 100
# 30 100
# 29 100
# 5 100
# 4 100
# 7 100
# 21 100
# 8 100
# 27 100
# 22 100
# 27 100
# 5 100
# 5 100
# 41 100
# 6 100
# 4 100
# 18 100
# 12 100
# 5 100
# 31 100
# 11 100
# 7 100
# 8 100
# 4 100
# 1 100
# 11 100
# 16 100
# 21 100
# 30 100
# 22 100
# 23 100
# 22 100
# 13 100
# 26 100
# 31 100
# 30 100
# 6 100
# 2 100
# 8 100
# 26 100
# 6 100
# 13 100
# 13 100
# 29 100
# 29 100
# 11 100
# 21 100
# 27 100
# 29 100
# 7 100
# 3 100
# 22 100
# 28 100
# 23 100
# 14 100
# 8 100
# 22 100
# 19 100
# 11 100
# 26 100
# 5 100
# 3 100
# 11 100
# 13 100
# 18 100
# 8 100
# 24 100
# 6 100
# 29 100
# 17 100
# 6 100
# 12 100
# 8 100
# 10 100
# 10 100
# 24 100
# 7 100
# 4 100
# 5 100
# 27 100
# 46 100
# 1 100
# 15 100
# 18 100
# 9 100
# 24 100
# 7 100
# 27 100
# 22 100
# 15 100
# 75 100
# 14 100
# 8 100
# 8 100
# 15 100
# 22 100
# 17 100
# 2 100
# 5 100
# 5 100
# 5 100
# 25 100
# 38 100
# 7 100
# 8 100
# 8 100
# 31 100
# 22 100
# 11 100
# 12 100
# 4 100
# 5 100
# 5 100
# 20 100
# 25 100
# 17 100
# 4 100
# 9 100
# 26 100
# 24 100
# 12 100
# 28 100
# 25 100
# 7 100
# 16 100
# 6 100
# 8 100
# 9 100
# 10 100
# 5 100
# 5 100
# 25 100
# 9 100
# 24 100
# 8 100
# 12 100
# 27 100
# 26 100
# 14 100
# 17 100
# 20 100
# 5 100
# 23 100
# 4 100
# 13 100
# 22 100
# 14 100
# 26 100
# 19 100
# 15 100
# 20 100
# 25 100
# 10 100
# 18 100
# 6 100
# 22 100
# 20 100
# 23 100
# 23 100
# 26 100
# 12 100
# 26 100
# 12 100
# 17 100
# 11 100
# 28 100
# 33 100
# 12 100
# 21 100
# 4 100
# 8 100
# 4 100
# 11 100
# 23 100
# 14 100
# 22 100
# 16 100
# 18 100
# 17 100
# 10 100
# 27 100
# 4 100
# 20 100
# 27 100
# 19 100
# 37 100
# 4 100
# 14 100
# 6 100
# 4 100
# 14 100
# 4 100
# 5 100
# 11 100
# 32 100
# 27 100
# 6 100
# 8 100
# 19 100
# 20 100
# 9 100
# 25 100
# 25 100
# 13 100
# 10 100
# 23 100
# 11 100
# 6 100
# 3 100
# 12 100
# 18 100
# 9 100
# 7 100
# 13 100
# 12 100
# 17 100
# 8 100
# 4 100
# 4 100
# 23 100
# 10 100
# 6 100
# 22 100
# 34 100
# 10 100
# 19 100
# 7 100
# 27 100
# 20 100
# 14 100
# 8 100
# 5 100
# 7 100
# 3 100
# 20 100
# 8 100
# 11 100
# 24 100
# 8 100
# 2 100
# 9 100
# 4 100
# 5 100
# 17 100
# 7 100
# 7 100
# 21 100
# 8 100
# 3 100
# 24 100
# 24 100
# 8 100
# 9 100
# 5 100
# 9 100
# 21 100
# 8 100
# 22 100
# 17 100
# 30 100
# 9 100
# 8 100
# 17 100
# 17 100
# 15 100
# 5 100
# 13 100
# 15 100
# 24 100
# 5 100
# 11 100
# 10 100
# 30 100
# 10 100
# 21 100
# 13 100
# 14 100
# 13 100
# 7 100
# 4 100
# 5 100
# 8 100
# 12 100
# 10 100
# 7 100
# 5 100
# 6 100
# 17 100
# 7 100
# 9 100
# 14 100
# 77 100
# 18 100
# 38 100
# 7 100
# 5 100
# 12 100
# 5 100
# 13 100
# 9 100
# 16 100
# 8 100
# 10 100
# 24 100
# 23 100
# 5 100
# 12 100
# 5 100
# 21 100
# 4 100
# 5 100
# 19 100
# 9 100
# 4 100
# 8 100
# 6 100
# 9 100
# 20 100
# 14 100
# 4 100
# 10 100
# 20 100
# 21 100
# 17 100
# 12 100
# 23 100
# 4 100
# 4 100
# 176 100
# 25 100
# 12 100
# 7 100
# 8 100
# 22 100
# 4 100
# 15 100
# 21 100
# 5 100
# 20 100
# 9 100
# 27 100
# 8 100
# 5 100
# 10 100
# 20 100
# 26 100
# 15 100
# 8 100
# 24 100
# 22 100
# 4 100
# 11 100
# 9 100
# 5 100
# 7 100
# 26 100
# 9 100
# 18 100
# 10 100
# 6 100
# 19 100
# 6 100
# 15 100
# 7 100
# 7 100
# 9 100
# 17 100
# 24 100
# 6 100
# 8 100
# 7 100
# 11 100
# 27 100
# 19 100
# 30 100
# 6 100
# 10 100
# 8 100
# 5 100
# 24 100
# 21 100
# 0 100
# 8 100
# 11 100
# 5 100
# 31 100
# 21 100
# 6 100
# 8 100
# 15 100
# 44 100
# 7 100
# 8 100
# 5 100
# 10 100
# 3 100
# 23 100
# 13 100
# 27 100
# 12 100
# 4 100
# 30 100
# 23 100
# 20 100
# 5 100
# 34 100
# 21 100
# 22 100
# 5 100
# 31 100
# 1 100
# 7 100
# 14 100
# 22 100
# 4 100
# 8 100
# 17 100
# 12 100
# 9 100
# 3 100
# 20 100
# 25 100
# 16 100
# 5 100
# 6 100
# 13 100
# 19 100
# 28 100
# 16 100
# 7 100
# 38 100
# 8 100
# 20 100
# 30 100
# 7 100
# 16 100
# 28 100
# 21 100
# 7 100
# 25 100
# 14 100
# 5 100
# 13 100
# 22 100
# 6 100
# 10 100
# 41 100
# 8 100
# 17 100
# 2 100
# 17 100
# 13 100
# 23 100
# 5 100
# 6 100
# 27 100
# 19 100
# 6 100
# 15 100
# 11 100
# 18 100
# 18 100
# 23 100
# 12 100
# 13 100
# 58 100
# 15 100
# 12 100
# 22 100
# 16 100
# 4 100
# 7 100
# 5 100
# 1 100
# 21 100
# 22 100
# 16 100
# 8 100
# 7 100
# 28 100
# 5 100
# 19 100
# 29 100
# 5 100
# 6 100
# 7 100
# 26 100
# 11 100
# 12 100
# 27 100
# 4 100
# 10 100
# 16 100
# 20 100
# 46 100
# 2 100
# 16 100
# 7 100
# 12 100
# 21 100
# 11 100
# 8 100
# 4 100
# 13 100
# 8 100
# 12 100
# 5 100
# 24 100
# 9 100
# 14 100
# 21 100
# 11 100
# 25 100
# 24 100
# 16 100
# 4 100
# 19 100
# 4 100
# 4 100
# 2 100
# 36 100
# 16 100
# 15 100
# 9 100
# 13 100
# 21 100
# 10 100
# 9 100
